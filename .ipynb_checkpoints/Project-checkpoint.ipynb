# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import os
import numpy as np
from tkinter import Tk
from tkinter.filedialog import askdirectory
path = askdirectory(title='Select Folder') # shows dialog box and return the path
os.path.abspath(path)
files = glob.glob(os.path.join(path, "*.csv"))
path1 = os.path.basename(os.path.normpath(path))

dataframe_list = []
#note, for naming. The file (aggregate freq/amp, waveform) data should be pretty concise. The waveform by itself should be named plainly (like 0.5) because it will be in its own folder and analyzed
#waveform data should be aggregated together (like ratio) and put into one folder for the entire system. 
for path, dirs, files in os.walk(path):
    print("Path:", path)

    print ("\nDirs:")
    for d in dirs:
        print ('\t'+d)

    
        
    print ("\nFiles:")  


    for f in files:
        
        #filename = os.path.basename(f).split('.')[0] + "." + os.path.basename(f).split('.')[1]
        #strain = filename.split('-')[0].replace("%","")
        
        if(f.endswith('.csv')) :
            
            #NEED A WAY TO GET FREQUENCY
            fullfile = path +"/" +f#+".csv"
            if(fullfile.endswith('.csv')):
                pass
            else:
                fullfile += ".csv"
            fullfile = path +"/" +f#+".csv"
            print(fullfile)
            #data splitting
            name_data = f.split('_')
            if(len(name_data) == 4):
                wt_percent = int(name_data[0][0])
                replicate = int(name_data[1])
                raw_strain = float(name_data[2].replace(".csv", "").replace("xyz","0.1").replace("strain","").replace("_save", ""))
            else:
                wt_percent = int(name_data[0][0])
                replicate = 1
                raw_strain = float(name_data[1].replace(".csv", "").replace("xyz","0.1").replace("strain","").replace("_save", ""))
            
            
           #opendataframe
        
            dataframe1 = pd.read_csv(fullfile)
            dataframe1["strain"] = raw_strain
            dataframe1["wt_percent"] = wt_percent
            
            dataframe_list.append(dataframe1)
            print(dataframe1.size)
            
            
            

            
            #plotData(data1,name, n)
           
                


    
        
        
        
        
    print("Finished for loop")
       

        
        
    print ("----")
full_df = pd.concat(dataframe_list).reset_index()
full_df2 = full_df.copy()
print(full_df)
# Out:
# Path: C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt
#
# Dirs:
#
# Files:
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/1cda_2_1000strain_save.csv
# 15264
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/1cda_2_100strain_save.csv
# 13368
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/1cda_2_10strain_save.csv
# 15048
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/1cda_2_1strain_save.csv
# 15288
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/1cda_2_200strain_save.csv
# 13168
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/1cda_2_20strain_save.csv
# 15864
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/1cda_2_30strain_save.csv
# 15848
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/1cda_2_40strain_save.csv
# 15752
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/1cda_2_50strain_save.csv
# 15128
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/1cda_2_630strain_save.csv
# 15008
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/1cda_2_63strain_save.csv
# 15112
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/1cda_2_80strain_save.csv
# 14352
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/1cda_2_xyz_save.csv
# 16176
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/1cda_3_1000strain_save.csv
# 16488
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/1cda_3_100strain_save.csv
# 11608
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/1cda_3_10strain_save.csv
# 11976
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/1cda_3_1strain_save.csv
# 12976
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/1cda_3_200strain_save.csv
# 12648
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/1cda_3_20strain_save.csv
# 12056
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/1cda_3_30strain_save.csv
# 13112
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/1cda_3_40strain_save.csv
# 13088
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/1cda_3_50strain_save.csv
# 13320
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/1cda_3_630strain_save.csv
# 16512
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/1cda_3_63strain_save.csv
# 13040
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/1cda_3_80strain_save.csv
# 13680
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/1cda_3_xyz_save.csv
# 12048
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/1percent_1000strain_save.csv
# 15360
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/1percent_100strain_save.csv
# 14616
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/1percent_10strain_save.csv
# 13200
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/1percent_1strain_save.csv
# 11904
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/1percent_200strain_save.csv
# 15256
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/1percent_20strain_save.csv
# 14032
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/1percent_30strain_save.csv
# 14352
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/1percent_40strain_save.csv
# 13440
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/1percent_50strain_save.csv
# 13456
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/1percent_630strain_save.csv
# 12704
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/1percent_63strain_save.csv
# 14568
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/1percent_80strain_save.csv
# 14544
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/1percent_xyz_save.csv
# 12184
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/2cda_2_1000strain_save.csv
# 18472
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/2cda_2_100strain_save.csv
# 20144
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/2cda_2_10strain_save.csv
# 19064
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/2cda_2_1strain_save.csv
# 19376
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/2cda_2_200strain_save.csv
# 15016
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/2cda_2_20strain_save.csv
# 19896
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/2cda_2_30strain_save.csv
# 19488
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/2cda_2_40strain_save.csv
# 19584
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/2cda_2_50strain_save.csv
# 19296
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/2cda_2_630strain_save.csv
# 17456
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/2cda_2_63strain_save.csv
# 19072
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/2cda_2_80strain_save.csv
# 19584
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/2cda_2_xyz_save.csv
# 19824
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/2cda_3_1000strain_save.csv
# 14832
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/2cda_3_100strain_save.csv
# 12496
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/2cda_3_10strain_save.csv
# 12336
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/2cda_3_1strain_save.csv
# 11600
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/2cda_3_200strain_save.csv
# 12168
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/2cda_3_20strain_save.csv
# 12920
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/2cda_3_30strain_save.csv
# 12784
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/2cda_3_40strain_save.csv
# 13208
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/2cda_3_50strain_save.csv
# 12632
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/2cda_3_630strain_save.csv
# 11880
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/2cda_3_63strain_save.csv
# 12400
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/2cda_3_80strain_save.csv
# 12360
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/2cda_3_xyz_save.csv
# 12416
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/2percent_1000strain_save.csv
# 15784
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/2percent_100strain_save.csv
# 14648
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/2percent_10strain_save.csv
# 16352
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/2percent_1strain_save.csv
# 15720
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/2percent_200strain_save.csv
# 16120
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/2percent_20strain_save.csv
# 15952
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/2percent_30strain_save.csv
# 15528
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/2percent_40strain_save.csv
# 16296
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/2percent_50strain_save.csv
# 15296
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/2percent_630strain_save.csv
# 14744
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/2percent_63strain_save.csv
# 15520
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/2percent_80strain_save.csv
# 15048
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/2percent_xyz_save.csv
# 16592
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/4percent_100strain_save.csv
# 19736
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/4percent_10strain_save.csv
# 21048
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/4percent_1strain_save.csv
# 19704
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/4percent_200strain_save.csv
# 18728
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/4percent_20strain_save.csv
# 21264
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/4percent_30strain_save.csv
# 21072
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/4percent_40strain_save.csv
# 21384
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/4percent_50strain_save.csv
# 20792
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/4percent_630strain_save.csv
# 20168
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/4percent_63strain_save.csv
# 18928
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/4percent_80strain_save.csv
# 19400
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/Data/alt/4percent_xyz_save.csv
# 19472
# Finished for loop
# ----
#         index  Unnamed: 0     radius           x           y           z  \
# 0           0          43  10.663017  137.971887  169.588733   19.544326
# 1           1          46  14.259466   53.585394  328.401780   16.351060
# 2           2          48   4.070835  178.080761  268.122702   15.062729
# 3           3          50  10.108923  298.410727   63.881591   15.816227
# 4           4          51   4.255959  275.825935  117.487985   16.153896
# ...       ...         ...        ...         ...         ...         ...
# 175388   2429        3289  14.570432  157.544378  247.526141  114.037510
# 175389   2430        3290  15.123183   75.418357  191.771986  130.215336
# 175390   2431        3292  15.097880  109.758339  199.962721  139.609974
# 175391   2432        3293  14.213091  259.523616  338.388994  151.966200
# 175392   2433        3294  14.730645   33.998972  201.796774  170.061095
#
#         neighbors  strain  wt_percent
# 0               3  1000.0           1
# 1               5  1000.0           1
# 2               1  1000.0           1
# 3               3  1000.0           1
# 4               2  1000.0           1
# ...           ...     ...         ...
# 175388          6     0.1           4
# 175389          5     0.1           4
# 175390          6     0.1           4
# 175391          6     0.1           4
# 175392          7     0.1           4
#
# [175393 rows x 9 columns]

# %%
import matplotlib.colors as mcolors
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
#wt_percent = 4
full_df = full_df2.copy()
full_df = full_df[full_df["strain"]>0]
full_df = full_df[full_df["x"]<300]
full_df = full_df[full_df["x"]>50]

full_df = full_df[full_df["y"]<300]
full_df = full_df[full_df["y"]>50 ]

full_df = full_df[full_df["z"]>50]
full_df = full_df[full_df["z"]<150]

full_df = full_df[full_df["radius"]<100]
full_df = full_df[full_df["radius"]>0]


#full_df = full_df[full_df["wt_percent"]==wt_percent]
full_df['logradius'] = np.log10(full_df['radius'])
full_df['volume'] = 3.14*full_df['radius']**2 


strains = full_df['strain'].unique()
wt_percent = full_df['wt_percent'].unique()

for wt in wt_percent:
    for strain in strains:
        break
        full_df1 = full_df[full_df["strain"]==strain]

        a1 = sns.histplot(data = full_df1, x = "radius", bins = 30)
        a1.set(xlim = (0,60), ylim=(0,600))
        plt.savefig("./data/AmplitudeSweeps/Figures/"+str(wt)+"wtpercent"+str(strain)+"strain"+".png")

        #plt.show()
        #full_df1.to_csv("./data/AmplitudeSweeps/Data/"+"histdata"+str(strain)+"wtpercent"+ str(wt)+".csv")

    
    
# Create bins with a specified width
bin_width = 0.5
# Calculate the maximum bin edge as the nearest upper multiple of bin_width
max_bin_edge = np.ceil(full_df['radius'].max() / bin_width) * bin_width
# Create an array of bin edges from 0 to max_bin_edge with a step of bin_width
bins = np.arange(0, max_bin_edge + bin_width, bin_width)

# Bin the data using pd.cut
full_df['radius_bin'] = pd.cut(full_df['radius'], bins=bins, include_lowest=True, right=False)

# Calculate summary statistics for each bin
summary_data = full_df.groupby([ "strain",'radius_bin']).sum().reset_index()
summary_data_2 = full_df.groupby([ "strain",'radius_bin']).mean().reset_index()  

# Rename columns in summary_data to append '_sum'
summary_data = summary_data.rename(columns={col: f'{col}_sum' for col in summary_data.columns if col not in ['strain', 'radius_bin']})

# Rename columns in summary_data_2 to append '_mean'
summary_data_2 = summary_data_2.rename(columns={col: f'{col}_mean' for col in summary_data_2.columns if col not in ['strain', 'radius_bin']})

# Step 2: Merge DataFrames on 'radius_bin'
combined_data = pd.merge(summary_data, summary_data_2,on=['strain', 'radius_bin'])

print(combined_data.head())
combined_data = combined_data.dropna()
combined_data['radius_mean'] = pd.to_numeric(combined_data['radius_mean'], errors='coerce')
combined_data['radius_mean'].fillna(0, inplace=True)
combined_data['radius_mean'] = combined_data['radius_mean'].astype(float)

combined_data["normalizedVolume"] = combined_data["volume_sum"]/(201*350*350)*100
combined_data['radius_mean'] = np.round(combined_data['radius_mean'],1)


#combined_data["radius_mean"] = float(combined_data["radius_mean"])
    
strains = combined_data['strain'].unique()
for wt in wt_percent:

    for strain in strains:
        print(strain)
        break
        combined_data1 = combined_data[combined_data["strain"]==strain]
        #combined_data1 = combined_data1[combined_data1["wt_percent"]==wt]
        

        a1 = sns.barplot(data = combined_data1, x = "radius_mean", y = "normalizedVolume")


        a1.set(xlim = (0,90), ylim = (0,0.35))
        # Select every Nth label to display
        n = 10  # Adjust based on your needs
        for index, label in enumerate(a1.xaxis.get_ticklabels()):
            if index % n != 0:
                label.set_visible(False)
        a1.set(xlabel ="Radius [micron]", ylabel = "Normalized Volume [-]")
        plt.tight_layout()
        plt.savefig("./data/AmplitudeSweeps/Figures/"+"hist"+str(strain)+"wtpercent-"+str(wt)+".png")
        plt.clf()
        #plt.show()    

        combined_data1.to_csv("./data/AmplitudeSweeps/Data/"+"histdata"+str(strain)+"wtpercent"+ str(wt)+".csv")
    
    
    
    
    
    
    
    
    
    
    
    



full_df['logstrain'] = np.log10(full_df['strain'])


print(full_df)


fig = plt.figure()

ax = fig.add_subplot(111, projection='3d')
ax.scatter(full_df["logstrain"] , full_df["radius"], full_df["neighbors"] , c = full_df["wt_percent"])

#X, Y = np.meshgrid(x_range, y_range)
#Z = Model.ev(X,Y)
#ax.plot_surface(X,Y,Z, color='red', alpha=0.5)

ax.set_xlabel('strain')
ax.set_ylabel('rad')
ax.set_zlabel('neighbors')
plt.show()

full_df["ratio"] = full_df["neighbors"]/full_df["radius"]**2
a1 = sns.lineplot(data = full_df, x = "strain", y = "ratio",  hue = "wt_percent",palette = "flare")
a1.set(xscale='log')
a1.set(ylim = (0,0.1))



plt.show()

a1 = sns.lineplot(data = full_df, x = "strain", y = "neighbors",  hue = "wt_percent",palette = "flare")
a1.set(xscale='log')
a1.set(ylim = (0,10))

plt.savefig("neighbors.png", format = 'png', dpi = 800)
plt.show()

a1 = sns.lineplot(data = full_df, x = "strain", y = "radius",  hue = "wt_percent",palette = "flare")
a1.set(xscale='log')



plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [10], line 20
#      16 full_df = full_df[full_df["radius"]<100]
#      17 full_df = full_df[full_df["radius"]>0]
# ---> 20 full_df = full_df[full_df["wt_percent"]==wt_percent]
#      21 full_df['logradius'] = np.log10(full_df['radius'])
#      22 full_df['volume'] = 3.14*full_df['radius']**2
#
# File C:\Users\Public\COnda\envs\pandas\lib\site-packages\pandas\core\ops\common.py:65, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      61             return NotImplemented
#      63 other = item_from_zerodim(other)
# ---> 65 return method(self, other)
#
# File C:\Users\Public\COnda\envs\pandas\lib\site-packages\pandas\core\arraylike.py:29, in OpsMixin.__eq__(self, other)
#      27 @unpack_zerodim_and_defer("__eq__")
#      28 def __eq__(self, other):
# ---> 29     return self._cmp_method(other, operator.eq)
#
# File C:\Users\Public\COnda\envs\pandas\lib\site-packages\pandas\core\series.py:4978, in Series._cmp_method(self, other, op)
#    4975 lvalues = extract_array(self, extract_numpy=True)
#    4976 rvalues = extract_array(other, extract_numpy=True)
# -> 4978 res_values = ops.comparison_op(lvalues, rvalues, op)
#    4980 return self._construct_result(res_values, name=res_name)
#
# File C:\Users\Public\COnda\envs\pandas\lib\site-packages\pandas\core\ops\array_ops.py:223, in comparison_op(left, right, op)
#     218 if isinstance(rvalues, (np.ndarray, ABCExtensionArray)):
#     219     # TODO: make this treatment consistent across ops and classes.
#     220     #  We are not catching all listlikes here (e.g. frozenset, tuple)
#     221     #  The ambiguous case is object-dtype.  See GH#27803
#     222     if len(lvalues) != len(rvalues):
# --> 223         raise ValueError(
#     224             "Lengths must match to compare", lvalues.shape, rvalues.shape
#     225         )
#     227 if should_extension_dispatch(lvalues, rvalues):
#     228     # Call the method on lvalues
#     229     res_values = op(lvalues, rvalues)
#
# ValueError: ('Lengths must match to compare', (61448,), (1,))
