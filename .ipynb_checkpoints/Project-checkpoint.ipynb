# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import os
import numpy as np
from tkinter import Tk
from tkinter.filedialog import askdirectory
path = askdirectory(title='Select Folder') # shows dialog box and return the path
os.path.abspath(path)
files = glob.glob(os.path.join(path, "*.csv"))
path1 = os.path.basename(os.path.normpath(path))

dataframe_list = []
#note, for naming. The file (aggregate freq/amp, waveform) data should be pretty concise. The waveform by itself should be named plainly (like 0.5) because it will be in its own folder and analyzed
#waveform data should be aggregated together (like ratio) and put into one folder for the entire system. 
for path, dirs, files in os.walk(path):
    print("Path:", path)

    print ("\nDirs:")
    for d in dirs:
        print ('\t'+d)

    
        
    print ("\nFiles:")  


    for f in files:
        
        #filename = os.path.basename(f).split('.')[0] + "." + os.path.basename(f).split('.')[1]
        #strain = filename.split('-')[0].replace("%","")
        
        if(f.endswith('.csv')) :
            
            #NEED A WAY TO GET FREQUENCY
            fullfile = path +"/" +f#+".csv"
            if(fullfile.endswith('.csv')):
                pass
            else:
                fullfile += ".csv"
            fullfile = path +"/" +f#+".csv"
            print(fullfile)
            #data splitting
            name_data = f.split('_')
            wt_percent = int(name_data[0][0])
            raw_strain = float(name_data[1].replace(".csv", "").replace("xyz","0.1").replace("strain","").replace("_save", ""))
            
            
           #opendataframe
        
            dataframe1 = pd.read_csv(fullfile)
            dataframe1["strain"] = raw_strain
            dataframe1["wt_percent"] = wt_percent
            
            dataframe_list.append(dataframe1)
            print(dataframe1.size)
            
            
            

            
            #plotData(data1,name, n)
           
                


    
        
        
        
        
    print("Finished for loop")
       

        
        
    print ("----")
full_df = pd.concat(dataframe_list).reset_index()
print(full_df)
# Out:
# Path: C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/AmplitudeSweeps_ParticleData/FinalData
#
# Dirs:
#
# Files:
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/AmplitudeSweeps_ParticleData/FinalData/1percent_1000strain_save.csv
# 15360
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/AmplitudeSweeps_ParticleData/FinalData/1percent_100strain_save.csv
# 14616
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/AmplitudeSweeps_ParticleData/FinalData/1percent_10strain_save.csv
# 13200
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/AmplitudeSweeps_ParticleData/FinalData/1percent_1strain_save.csv
# 11904
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/AmplitudeSweeps_ParticleData/FinalData/1percent_200strain_save.csv
# 15256
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/AmplitudeSweeps_ParticleData/FinalData/1percent_20strain_save.csv
# 14032
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/AmplitudeSweeps_ParticleData/FinalData/1percent_30strain_save.csv
# 14352
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/AmplitudeSweeps_ParticleData/FinalData/1percent_40strain_save.csv
# 13440
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/AmplitudeSweeps_ParticleData/FinalData/1percent_50strain_save.csv
# 13456
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/AmplitudeSweeps_ParticleData/FinalData/1percent_630strain_save.csv
# 12704
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/AmplitudeSweeps_ParticleData/FinalData/1percent_63strain_save.csv
# 14568
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/AmplitudeSweeps_ParticleData/FinalData/1percent_80strain_save.csv
# 14544
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/AmplitudeSweeps_ParticleData/FinalData/1percent_xyz_save.csv
# 12184
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/AmplitudeSweeps_ParticleData/FinalData/2percent_1000strain_save.csv
# 15784
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/AmplitudeSweeps_ParticleData/FinalData/2percent_100strain_save.csv
# 14648
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/AmplitudeSweeps_ParticleData/FinalData/2percent_10strain_save.csv
# 16352
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/AmplitudeSweeps_ParticleData/FinalData/2percent_1strain_save.csv
# 15720
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/AmplitudeSweeps_ParticleData/FinalData/2percent_200strain_save.csv
# 16120
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/AmplitudeSweeps_ParticleData/FinalData/2percent_20strain_save.csv
# 15952
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/AmplitudeSweeps_ParticleData/FinalData/2percent_30strain_save.csv
# 15528
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/AmplitudeSweeps_ParticleData/FinalData/2percent_40strain_save.csv
# 16296
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/AmplitudeSweeps_ParticleData/FinalData/2percent_50strain_save.csv
# 15296
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/AmplitudeSweeps_ParticleData/FinalData/2percent_630strain_save.csv
# 14744
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/AmplitudeSweeps_ParticleData/FinalData/2percent_63strain_save.csv
# 15520
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/AmplitudeSweeps_ParticleData/FinalData/2percent_80strain_save.csv
# 15048
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/AmplitudeSweeps_ParticleData/FinalData/2percent_xyz_save.csv
# 16592
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/AmplitudeSweeps_ParticleData/FinalData/4percent_100strain_save.csv
# 19736
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/AmplitudeSweeps_ParticleData/FinalData/4percent_10strain_save.csv
# 21048
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/AmplitudeSweeps_ParticleData/FinalData/4percent_1strain_save.csv
# 19704
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/AmplitudeSweeps_ParticleData/FinalData/4percent_200strain_save.csv
# 18728
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/AmplitudeSweeps_ParticleData/FinalData/4percent_20strain_save.csv
# 21264
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/AmplitudeSweeps_ParticleData/FinalData/4percent_30strain_save.csv
# 21072
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/AmplitudeSweeps_ParticleData/FinalData/4percent_40strain_save.csv
# 21384
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/AmplitudeSweeps_ParticleData/FinalData/4percent_50strain_save.csv
# 20792
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/AmplitudeSweeps_ParticleData/FinalData/4percent_630strain_save.csv
# 20168
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/AmplitudeSweeps_ParticleData/FinalData/4percent_63strain_save.csv
# 18928
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/AmplitudeSweeps_ParticleData/FinalData/4percent_80strain_save.csv
# 19400
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweeps/AmplitudeSweeps_ParticleData/FinalData/4percent_xyz_save.csv
# 19472
# Finished for loop
# ----
#        index  Unnamed: 0     radius           x           y           z  \
# 0          0          76   3.962005  280.712642   21.921224   15.021454
# 1          1          79   3.952183  211.108642  127.022801   15.097796
# 2          2          81   3.952154   38.756194  199.822572   15.005739
# 3          3          83   3.915716  201.370938  327.220324   15.047814
# 4          4          85   3.914295   81.259666   24.016542   16.098152
# ...      ...         ...        ...         ...         ...         ...
# 78109   2429        3289  14.570432  157.544378  247.526141  114.037510
# 78110   2430        3290  15.123183   75.418357  191.771986  130.215336
# 78111   2431        3292  15.097880  109.758339  199.962721  139.609974
# 78112   2432        3293  14.213091  259.523616  338.388994  151.966200
# 78113   2433        3294  14.730645   33.998972  201.796774  170.061095
#
#        neighbors  strain  wt_percent
# 0              0  1000.0           1
# 1              0  1000.0           1
# 2              0  1000.0           1
# 3              0  1000.0           1
# 4              0  1000.0           1
# ...          ...     ...         ...
# 78109          6     0.1           4
# 78110          5     0.1           4
# 78111          6     0.1           4
# 78112          6     0.1           4
# 78113          7     0.1           4
#
# [78114 rows x 9 columns]

# %%
import matplotlib.colors as mcolors
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
full_df = full_df[full_df["strain"]>0]
full_df = full_df[full_df["x"]<300]
full_df = full_df[full_df["x"]>50]

full_df = full_df[full_df["y"]<300]
full_df = full_df[full_df["y"]>50 ]

full_df = full_df[full_df["z"]>50]
full_df = full_df[full_df["z"]<150]

full_df = full_df[full_df["radius"]<100]
full_df = full_df[full_df["radius"]>0]


#full_df = full_df[full_df["wt_percent"]==2]
full_df['logradius'] = np.log10(full_df['radius'])
full_df['volume'] = 3.14*full_df['radius']**2 


strains = full_df['strain'].unique()
wt_percent = full_df['wt_percent'].unique()

for wt in wt_percent:
    for strain in strains:
        
        full_df1 = full_df[full_df["strain"]==strain]

        a1 = sns.histplot(data = full_df1, x = "radius", bins = 30)
        a1.set(xlim = (0,60), ylim=(0,600))
        plt.savefig("./data/AmplitudeSweeps/Figures/"+str(wt)+"wtpercent"+str(strain)+"strain"+".png")

        plt.show()


    
    
# Create bins with a specified width
bin_width = 0.5
# Calculate the maximum bin edge as the nearest upper multiple of bin_width
max_bin_edge = np.ceil(full_df['radius'].max() / bin_width) * bin_width
# Create an array of bin edges from 0 to max_bin_edge with a step of bin_width
bins = np.arange(0, max_bin_edge + bin_width, bin_width)

# Bin the data using pd.cut
full_df['radius_bin'] = pd.cut(full_df['radius'], bins=bins, include_lowest=True, right=False)

# Calculate summary statistics for each bin
summary_data = full_df.groupby([ "strain",'radius_bin']).sum().reset_index()
summary_data_2 = full_df.groupby([ "strain",'radius_bin']).mean().reset_index()  

# Rename columns in summary_data to append '_sum'
summary_data = summary_data.rename(columns={col: f'{col}_sum' for col in summary_data.columns if col not in ['strain', 'radius_bin']})

# Rename columns in summary_data_2 to append '_mean'
summary_data_2 = summary_data_2.rename(columns={col: f'{col}_mean' for col in summary_data_2.columns if col not in ['strain', 'radius_bin']})

# Step 2: Merge DataFrames on 'radius_bin'
combined_data = pd.merge(summary_data, summary_data_2,on=['strain', 'radius_bin'])

print(combined_data.head())
combined_data = combined_data.dropna()
combined_data['radius_mean'] = pd.to_numeric(combined_data['radius_mean'], errors='coerce')
combined_data['radius_mean'].fillna(0, inplace=True)
combined_data['radius_mean'] = combined_data['radius_mean'].astype(float)

combined_data["normalizedVolume"] = combined_data["volume_sum"]/(201*350*350)*100
combined_data['radius_mean'] = np.round(combined_data['radius_mean'],1)


#combined_data["radius_mean"] = float(combined_data["radius_mean"])
    
strains = combined_data['strain'].unique()
    
for strain in strains:
    print(strain)
    break
    combined_data1 = combined_data[combined_data["strain"]==strain]
    
    a1 = sns.barplot(data = combined_data1, x = "radius_mean", y = "normalizedVolume")


    a1.set(xlim = (0,60), ylim = (0,0.35))
    # Select every Nth label to display
    n = 10  # Adjust based on your needs
    for index, label in enumerate(a1.xaxis.get_ticklabels()):
        if index % n != 0:
            label.set_visible(False)
    a1.set(xlabel ="Radius [micron]", ylabel = "Normalized Volume [-]")
    plt.tight_layout()
    plt.savefig("./data/AmplitudeSweeps/Figures/"+"hist"+str(strain)+".png")

    plt.show()    
    
    
    
    
    
    
    
    
    
    
    
    



full_df['logstrain'] = np.log10(full_df['strain'])


print(full_df)


fig = plt.figure()

ax = fig.add_subplot(111, projection='3d')
ax.scatter(full_df["logstrain"] , full_df["radius"], full_df["neighbors"] , c = full_df["wt_percent"])

#X, Y = np.meshgrid(x_range, y_range)
#Z = Model.ev(X,Y)
#ax.plot_surface(X,Y,Z, color='red', alpha=0.5)

ax.set_xlabel('strain')
ax.set_ylabel('rad')
ax.set_zlabel('neighbors')
plt.show()

full_df["ratio"] = full_df["neighbors"]/full_df["radius"]**2
a1 = sns.lineplot(data = full_df, x = "strain", y = "ratio",  hue = "wt_percent",palette = "flare")
a1.set(xscale='log')
a1.set(ylim = (0,0.1))



plt.show()

a1 = sns.lineplot(data = full_df, x = "strain", y = "neighbors",  hue = "wt_percent",palette = "flare")
a1.set(xscale='log')
a1.set(ylim = (0,10))

plt.savefig("neighbors.png", format = 'png', dpi = 800)
plt.show()

a1 = sns.lineplot(data = full_df, x = "strain", y = "radius",  hue = "wt_percent",palette = "flare")
a1.set(xscale='log')



plt.show()
# Out:
#    strain  radius_bin  index_sum  Unnamed: 0_sum  radius_sum       x_sum  \
# 0     0.1  [0.0, 0.5)        169             274    0.352216  158.853237
# 1     0.1  [0.5, 1.0)          0               0    0.000000    0.000000
# 2     0.1  [1.0, 1.5)          0               0    0.000000    0.000000
# 3     0.1  [1.5, 2.0)       1408            2199    5.187080  496.520795
# 4     0.1  [2.0, 2.5)       1345            1857    2.104316  170.994784
#
#         y_sum       z_sum  neighbors_sum  wt_percent_sum  ...  radius_mean  \
# 0  266.949031   62.977751              1               1  ...     0.352216
# 1    0.000000    0.000000              0               0  ...          NaN
# 2    0.000000    0.000000              0               0  ...          NaN
# 3  511.588240  314.601544              1               3  ...     1.729027
# 4   92.044823  123.963112              0               4  ...     2.104316
#
#        x_mean      y_mean      z_mean  neighbors_mean  wt_percent_mean  \
# 0  158.853237  266.949031   62.977751        1.000000              1.0
# 1         NaN         NaN         NaN             NaN              NaN
# 2         NaN         NaN         NaN             NaN              NaN
# 3  165.506932  170.529413  104.867181        0.333333              1.0
# 4  170.994784   92.044823  123.963112        0.000000              4.0
#
#    logradius_mean  volume_mean  logstrain_mean  ratio_mean
# 0       -0.453190     0.389537            -1.0    8.060846
# 1             NaN          NaN             NaN         NaN
# 2             NaN          NaN             NaN         NaN
# 3        0.236208     9.458241            -1.0    0.131074
# 4        0.323111    13.904374            -1.0    0.000000
#
# [5 rows x 26 columns]
# 0.1
#        index  Unnamed: 0     radius           x           y           z  \
# 150      150         261   3.989986  155.751970  276.984626   51.101045
# 151      151         262   4.262425   93.049531  187.172521   53.998219
# 152      152         263   4.590440  236.066939  226.926496   58.153753
# 153      153         264   4.060863  296.892642   74.186526   55.012380
# 154      154         265   4.190553  126.756009   90.364262   55.073324
# ...      ...         ...        ...         ...         ...         ...
# 78078   2398        3245  11.331328  293.859546  203.737991  149.917524
# 78102   2422        3282  14.687866  274.244158  169.962437   67.907365
# 78109   2429        3289  14.570432  157.544378  247.526141  114.037510
# 78110   2430        3290  15.123183   75.418357  191.771986  130.215336
# 78111   2431        3292  15.097880  109.758339  199.962721  139.609974
#
#        neighbors  strain  wt_percent  logradius      volume    radius_bin  \
# 150            0  1000.0           1   0.600971   49.988773    [3.5, 4.0)
# 151            2  1000.0           1   0.629657   57.048363    [4.0, 4.5)
# 152            3  1000.0           1   0.661854   66.166527    [4.5, 5.0)
# 153            1  1000.0           1   0.608618   51.780519    [4.0, 4.5)
# 154            3  1000.0           1   0.622271   55.140695    [4.0, 4.5)
# ...          ...     ...         ...        ...         ...           ...
# 78078          5     0.1           4   1.054281  403.172834  [11.0, 11.5)
# 78102          3     0.1           4   1.166959  677.402890  [14.5, 15.0)
# 78109          6     0.1           4   1.163472  666.614091  [14.5, 15.0)
# 78110          5     0.1           4   1.179643  718.151472  [15.0, 15.5)
# 78111          6     0.1           4   1.178916  715.750337  [15.0, 15.5)
#
#        logstrain     ratio
# 150          3.0  0.000000
# 151          3.0  0.110082
# 152          3.0  0.142368
# 153          3.0  0.060641
# 154          3.0  0.170836
# ...          ...       ...
# 78078       -1.0  0.038941
# 78102       -1.0  0.013906
# 78109       -1.0  0.028262
# 78110       -1.0  0.021862
# 78111       -1.0  0.026322
#
# [27294 rows x 14 columns]
