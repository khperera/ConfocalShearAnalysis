# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import os
import numpy as np
from tkinter import Tk
from tkinter.filedialog import askdirectory
path = askdirectory(title='Select Folder') # shows dialog box and return the path
os.path.abspath(path)
files = glob.glob(os.path.join(path, "*.csv"))
path1 = os.path.basename(os.path.normpath(path))

dataframe_list = []
#note, for naming. The file (aggregate freq/amp, waveform) data should be pretty concise. The waveform by itself should be named plainly (like 0.5) because it will be in its own folder and analyzed
#waveform data should be aggregated together (like ratio) and put into one folder for the entire system. 
for path, dirs, files in os.walk(path):
    print("Path:", path)

    print ("\nDirs:")
    for d in dirs:
        print ('\t'+d)

    
        
    print ("\nFiles:")  


    for f in files:
        
        #filename = os.path.basename(f).split('.')[0] + "." + os.path.basename(f).split('.')[1]
        #strain = filename.split('-')[0].replace("%","")
        
        if(f.endswith('.csv')) :
            
            #NEED A WAY TO GET FREQUENCY

            if(fullfile.endswith('.csv')):
                pass
            else:
                fullfile += ".csv"
            fullfile = path +"/" +f#+".csv"
            print(fullfile)
            #data splitting
            name_data = f.split('_')
            wt_percent = int(name_data[0][0])
            raw_strain = float(name_data[1].replace(".csv", "").replace("xyz","0.1").replace("strain",""))
            
            
           #opendataframe
        
            dataframe1 = pd.read_csv(fullfile)
            dataframe1["strain"] = raw_strain
            dataframe1["wt_percent"] = wt_percent
            
            dataframe_list.append(dataframe1)
            print(dataframe1.size)
            
            
            

            
            #plotData(data1,name, n)
           
                


    
        
        
        
        
    print("Finished for loop")
       

        
        
    print ("----")
full_df = pd.concat(dataframe_list).reset_index()
print(full_df)
# Out:
# Path: C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweep_Data
#
# Dirs:
#
# Files:
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweep_Data/1percent_1000strain.csv
# 17728
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweep_Data/1percent_100strain.csv
# 12656
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweep_Data/1percent_10strain.csv
# 11656
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweep_Data/1percent_1strain.csv
# 10424
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweep_Data/1percent_200strain.csv
# 15944
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweep_Data/1percent_20strain.csv
# 11976
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweep_Data/1percent_30strain.csv
# 11552
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweep_Data/1percent_40strain.csv
# 11832
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweep_Data/1percent_50strain.csv
# 12408
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweep_Data/1percent_630strain.csv
# 15056
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweep_Data/1percent_63strain.csv
# 11832
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweep_Data/1percent_80strain.csv
# 12960
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweep_Data/1percent_xyz.csv
# 9504
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweep_Data/2percent_1000strain.csv
# 17976
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweep_Data/2percent_100strain.csv
# 15144
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweep_Data/2percent_10strain.csv
# 16296
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweep_Data/2percent_1strain.csv
# 15256
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweep_Data/2percent_200strain.csv
# 14592
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweep_Data/2percent_20strain.csv
# 15240
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweep_Data/2percent_30strain.csv
# 15800
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweep_Data/2percent_40strain.csv
# 15840
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweep_Data/2percent_50strain.csv
# 15040
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweep_Data/2percent_630strain.csv
# 16272
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweep_Data/2percent_63strain.csv
# 14632
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweep_Data/2percent_80strain.csv
# 13704
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweep_Data/2percent_xyz.csv
# 15568
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweep_Data/4percent_100strain.csv
# 19368
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweep_Data/4percent_10strain.csv
# 19696
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweep_Data/4percent_1strain.csv
# 19480
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweep_Data/4percent_200strain.csv
# 17904
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweep_Data/4percent_20strain.csv
# 19912
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweep_Data/4percent_30strain.csv
# 19584
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweep_Data/4percent_40strain.csv
# 19280
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweep_Data/4percent_50strain.csv
# 19808
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweep_Data/4percent_630strain.csv
# 18408
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweep_Data/4percent_63strain.csv
# 20376
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweep_Data/4percent_80strain.csv
# 18296
# C:/Users/Himendra Perera/Documents/ProjectCode/CO2Diff/ConfocalShearAnalysis/data/AmplitudeSweep_Data/4percent_xyz.csv
# 19928
# Finished for loop
# ----
#        index  Unnamed: 0     radius           x           y           z  \
# 0          0           7   4.073133   43.050576  267.019362   15.014446
# 1          1          10   4.153514   41.777397  214.012885   15.968422
# 2          2          11   4.065099   35.128219  250.019444   15.994274
# 3          3          13   4.134072  105.069281   75.017006   17.051984
# 4          4          14   4.020656   83.939219  183.988986   17.026513
# ...      ...         ...        ...         ...         ...         ...
# 74861   2486        3444  16.451571  126.806206   52.046176   60.103371
# 74862   2487        3445  16.490774  295.977419  180.515119   67.498259
# 74863   2488        3446  16.235366   19.856518  284.632862   96.076527
# 74864   2489        3447  16.346359  118.992347  215.705299  135.497144
# 74865   2490        3449  20.110891   28.048085  197.330761   16.941685
#
#        neighbors  strain  wt_percent
# 0              2  1000.0           1
# 1              2  1000.0           1
# 2              1  1000.0           1
# 3              2  1000.0           1
# 4              2  1000.0           1
# ...          ...     ...         ...
# 74861         12     0.1           4
# 74862         12     0.1           4
# 74863          7     0.1           4
# 74864          6     0.1           4
# 74865          4     0.1           4
#
# [74866 rows x 9 columns]

# %%
full_df = full_df[full_df["strain"]>0]
full_df["ratio"] = full_df["neighbors"]/full_df["radius"]
a1 = sns.lineplot(data = full_df, x = "strain", y = "ratio",  hue = "wt_percent",palette = "flare")
a1.set(xscale='log')

plt.show()


a2 = sns.histplot(data=full_df, x="radius", hue="wt_percent")
plt.show()
